# %%
# Image 1
import numpy as np
import matplotlib.pyplot as plt
n = 11
data = np.zeros((n,n))

x = 0
for i in range(0,n):
    data[i,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+1,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+2,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+3,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+4,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+5,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+6,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+7,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+8,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+9,x] = 1
n = n - 1
x = x + 1
for i in range(0,n):
    data[i+10,x] = 1
n = n - 1
x = x + 1
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 2
import numpy as np
import matplotlib.pyplot as plt
n = 21
r = n//2
data = np.zeros((n,n))

x = r
for i in range(r,n):
    data[i-r,x] = 1
    x = x + 1
    
x = 0
for i in range(r,n):
    data[i,x] = 1
    n = n - 1
    x = x + 1
    
n = 21
x = r
for i in range(0,n):
    data[i,x] = 1

for i in range(0,n):
    data[x,i] = 1

x = 0
for i in range(0,r):
    data[i-r-1,x-1] = 1
    x = x - 1
    
x = 0
for i in range(0,r):
    data[i,x-r-1] = 1
    x = x - 1
    
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 3
import numpy as np
import matplotlib.pyplot as plt
n = 51
r = n//2
data = np.zeros((n,n))

z = 0
x = 0
total = 0
while total < r+1:
    total += 1 
    for i in range(r,n):
        data[i+z,x+r] = 1
    n = n - 1
    x = x + 1
    z = z + 1
    
z = 0
x = 0
total = 0
while total < r+1:
    total += 1 
    for i in range(0,n+1):
        data[i,x+r] = 1
    n = n - 1
    x = x + 1
    z = z + 1
    
z = 0
x = 0
total = 0
while total < r+1:
    total += 1 
    for i in range(-1,z):
        data[i+1,x] = 1
    x = x + 1
    z = z + 1
    
x = 0
p = n
total = 0
while total < r+1:
    total += 1 
    for i in range(p-1,n):
        data[i+1,x] = 1
    x = x + 1
    p = p - 1
    
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 4
import numpy as np
import matplotlib.pyplot as plt
n = 11
r = n//2
data = np.zeros((n,n))

z = 0
x = 0
total = 0
while total < n:
    total += 1 
    for i in range(0,n):
        if(x%2 == 0):
            if(i%2 == 0):
                data[i,x] = 1
        if(x%2 == 1):
            if(i%2 == 1):
                data[i,x] = 1
    x = x + 1
    
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 5
import numpy as np
import matplotlib.pyplot as plt
n = 13
r = n//2
data = np.zeros((n,n))

x = 0
for i in range(12,n):
    data[i,x] = 1
    x = x + 1

x = 0
for i in range(9,n):
    data[i,x] = 1
    x = x + 1
    
x = 0
for i in range(6,n):
    data[i,x] = 1
    x = x + 1

x = 0
for i in range(3,n):
    data[i,x] = 1
    x = x + 1
    
x = 0
for i in range(0,n):
    data[i,x] = 1
    x = x + 1
    
x = 0
for i in range(3,n):
    data[x,i]= 1
    x = x + 1
    
x = 0
for i in range(6,n):
    data[x,i]= 1
    x = x + 1
    
x = 0
for i in range(9,n):
    data[x,i]= 1
    x = x + 1
    
x = 0
for i in range(12,n):
    data[x,i]= 1
    x = x + 1
    
    
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 6
n = 501
r = n/2
data = np.zeros((n,n))

for x in range (0,n):
    for y in range(0,n):
        if ((x)**2+(y)**2)**(1/2) < r:
            data[x,y] = 1
            
for x in range (0,n):
    for y in range(0,n):
        if ((x-n)**2+(y)**2)**(1/2) < r:
            data[x,y] = 1
            
for x in range (0,n):
    for y in range(0,n):
        if ((x-n)**2+(y-n)**2)**(1/2) < r:
            data[x,y] = 1
            
for x in range (0,n):
    for y in range(0,n):
        if ((x)**2+(y-n)**2)**(1/2) < r:
            data[x,y] = 1
            
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 7
n = 321
n2 = 501
r = n/2
data = np.zeros((n2,n2))

for x in range (0,n2):
    for y in range(0,n2):
        if (((x-r-90)**2+(y-r)**2)**(1/2) < r):
            data[x,y] = 1
        if (((x-r-90)**2+(y-r-180)**2)**(1/2) < r):
            data[x,y] = 1
            if (((x-r-90)**2+(y-r)**2)**(1/2) < r):
                data[x,y] = 0
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Image 8 EC

n = 1001
n2 = 961
r = n/2
r2 = n2/2
n3 = 1051
r3 = n3/3
n4 = 151
r4 = n4/2
data = np.zeros((n,n))

            
for x in range (0,n):
    for y in range(0,n):
        if ((x-r)**2+(y-r)**2)**(1/2) > r:
            data[x,y] = 1
            
for x in range (0,n):
    for y in range(0,n):
        if ((x-r)**2+(y-r)**2)**(1/2) < r2:
            data[x,y] = 1

for x in range (640,n):
    for y in range(0,n):
        if ((x-r)**2+(y-r)**2)**(1/2) < r3:
            data[x,y] = 0
            
for x in range (0,n):
    for y in range(0,n):
        if ((x-340)**2+(y-320)**2)**(1/2) < r4:
            data[x,y] = 0
            
for x in range (0,n):
    for y in range(0,n):
        if ((x-340)**2+(y-663)**2)**(1/2) < r4:
            data[x,y] = 0
            
plt.imshow(data, interpolation='nearest')
plt.show()

# %%
# Part 2, Part A
import numpy as np
import matplotlib.pyplot as plt

H = np.loadtxt('topography_180x360_grid.txt')
print(H)
print(H.shape)
print(np.max(H)) #Highest elevation in the data set.
print(np.where(H == 5731.0)) #Coordinates of the highest point in the data set.
plt.imshow(data, interpolation='nearest')

H2 = H

H2[51:71,76:96] = 10000
plt.imshow(H2, interpolation='nearest')
plt.show()
# Out:
# [[-4298. -4299. -4300. ... -4292. -4294. -4296.]
#  [-4368. -4378. -4384. ... -4319. -4340. -4356.]
#  [-4425. -4419. -4418. ... -4387. -4409. -4422.]
#  ...
#  [ 2743.  2741.  2734. ...  2691.  2697.  2743.]
#  [ 2735.  2735.  2735. ...  2704.  2708.  2736.]
#  [ 2782.  2782.  2782. ...  2776.  2777.  2782.]]
# (180, 360)
# 5731.0
# (array([61], dtype=int64), array([86], dtype=int64))

# %%
# Part 2, Part B
import numpy as np
import matplotlib.pyplot as plt

H = np.loadtxt('topography_180x360_grid.txt')
print(H)
print(H.shape)
print(np.min(H)) #Lowest elevation in the data set.
print(np.where(H == -7473.0)) #Coordinates of the lowest point in the data set.
plt.imshow(data, interpolation='nearest')

H2 = H

H2[35:55,141:161] = -10000
plt.imshow(H2, interpolation='nearest')
plt.show()
# Out:
# [[-4298. -4299. -4300. ... -4292. -4294. -4296.]
#  [-4368. -4378. -4384. ... -4319. -4340. -4356.]
#  [-4425. -4419. -4418. ... -4387. -4409. -4422.]
#  ...
#  [ 2743.  2741.  2734. ...  2691.  2697.  2743.]
#  [ 2735.  2735.  2735. ...  2704.  2708.  2736.]
#  [ 2782.  2782.  2782. ...  2776.  2777.  2782.]]
# (180, 360)
# -7473.0
# (array([45], dtype=int64), array([151], dtype=int64))

# %%
# Part 2, Part C
import numpy as np
import matplotlib.pyplot as plt

H = np.loadtxt('topography_180x360_grid.txt')
print(H)
print(H.shape)
H = np.pad(H, pad_width=20, mode='constant', constant_values=10000)
plt.imshow(H, interpolation='nearest')
print(H)
print(H.shape)
plt.show()
# Out:
# [[-4298. -4299. -4300. ... -4292. -4294. -4296.]
#  [-4368. -4378. -4384. ... -4319. -4340. -4356.]
#  [-4425. -4419. -4418. ... -4387. -4409. -4422.]
#  ...
#  [ 2743.  2741.  2734. ...  2691.  2697.  2743.]
#  [ 2735.  2735.  2735. ...  2704.  2708.  2736.]
#  [ 2782.  2782.  2782. ...  2776.  2777.  2782.]]
# (180, 360)
# [[10000. 10000. 10000. ... 10000. 10000. 10000.]
#  [10000. 10000. 10000. ... 10000. 10000. 10000.]
#  [10000. 10000. 10000. ... 10000. 10000. 10000.]
#  ...
#  [10000. 10000. 10000. ... 10000. 10000. 10000.]
#  [10000. 10000. 10000. ... 10000. 10000. 10000.]
#  [10000. 10000. 10000. ... 10000. 10000. 10000.]]
# (220, 400)
