# %%
## Import necessary packages
# On Macs use osx
# For Windows use qt

import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['animation.ffmpeg_path']=r'C:\Users\lhamr\OneDrive\Desktop\ffmpeg.exe'

from numpy.random import rand
from landscapeWithOcean import LandscapeWithOcean # Import methods from inside file landscapeWithOcean.py

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
# %matplotlib qt

# %%
def AddHill(Z,NX,NY,xx,yy,r,h):

    for x in range(NX):
        for y in range(NY):
            dx = np.mod(x-xx+NX/2,NX)-NX/2; # difference i-i0 but apply p.b.c. 
            dy = np.mod(y-yy+NY/2,NY)-NY/2;
            dr = np.sqrt(dx**2+dy**2);
            if (dr<r):
                Z[x,y] += h * (np.cos(dr/r*np.pi/2.0))**2;

    return Z

# %%
### Define simulation grid and initial conditions

NX = 30*2 #number of rows | used to be 70*2
NY = 30*2 #number of columns | used to be 70*2
d  = 5 # grid spacing in meters
dx = d # keep dx=dy for simplicity
dy = d

LX=NX*dx
LY=NY*dy

# small random features in topography to begin erosion
n = NX
r = n//2 #VALUE OF R for circles 
Z = np.zeros((NX,NY))

for i in range(n): #fills a circle yellow
    for j in range(n):
        if (i-r)**2 + (j-r)**2 <= r**2: #(x-h)^2 + (y-k)^2 <= r^2 where (h,k) is origin
            Z[i,j] = 0.5
            
#copy previous but change value for A[i,j] from 1 to 0
for i in range(n//2): #vertical region from 0 to n//2
    for j in range(n): #horizontal region
        if i+j >= n//2 and j-i<=n//2: #left bound and right bound, longer region - smaller region <= n//2 to get downward diagonal bound
            Z[i,j] = 0.1
            xx = i
            yy = j
            r  = (0.5)*NX
            h  = (0.5)*1
            Z = AddHill(Z,NX,NY,xx,yy,r,h)
for i in range(n//2,n): #vertical region from n//2 to n
    for j in range(n):
        if i-j <= n//2 and j+i<=3*n//2: #think of what values of i and j is yellow (75+75)=150<=3*n//2
            Z[i,j] = 0.1
            xx = i
            yy = j
            r  = (0.5)*NX
            h  = (0.5)*1
            Z = AddHill(Z,NX,NY,xx,yy,r,h)

x = np.arange(NX)
y = np.arange(NY)
X,Y = np.meshgrid(y,x) #strange that y goes first !!!
ZMaxOrg = np.max(Z)
#print(ZMaxOrg)

# %%
### Physical Parameters
K = 1.0e-12 # meters^(1-2m)/yr | used to be 1.0e-6

D = 0.012 # m^2/yr | used to be 0.005

# uplift rate
# uplift = 0.03 / 600.
uplift = 0.0

# %%
### Model parameters

# Time step
dt = d**2 / D / 12. #used to be dt = d**2 / D / 8. 
#dt = d**2 / D /16. #extra small steps 
print(' dt[years] = ',dt)

#Area exponent A^m, default m=1
m=1.2

#gradient exponent g^n, default n=1
n=1.3

#erosion threshold 
theta_c = 10
# Out:
#  dt[years] =  173.61111111111111

# %%
# Total simulation time
T = 1000.0 * 100.0

# total number of iterations
n_iter = int(np.round(T/dt))
print('Number of interation: ',n_iter)
# Out:
# Number of interation:  576

# %%
# Initialize landscape 
ls = LandscapeWithOcean(NX,NY)

oceanLevelParameter=0.5  # what does this parameter do?
ls.ComputeOceanVolumeFromOceanLevelParameter(Z,NX,NY,oceanLevelParameter)

ls.pool_check(Z,NX,NY)
ls.A = np.zeros((NX,NY))
# Out:
# Minimum elevation           0.6
# Maximum elevation           220.64638403013174
# Beach level                 110.62319201506587
# Ocean volume                44776.107718719504
# Percentage of ocean surface 30.5

# %%
# Set-up figure
def init_figure():
    fig = plt.figure(figsize=(12.,6.))
    plt.show()
    return fig

def update_figure():
        plt.clf()
        ax1 = fig.add_subplot(121,projection='3d')

        # use equal x-y aspect with an explicit vertical exageration
        vert_exag = 4.
        ax1.set_xlim3d(0,max(NX,NY))
        ax1.set_ylim3d(0,max(NX,NY))
        ax1.set_zlim3d(0,ZMaxOrg)

        ax1.set_title('Surface Relief')

#        surf = ax1.plot_surface(X,Y,Z, cmap = cm.terrain, rstride=1, cstride=1,
#                antialiased=False,linewidth=0)

        ZPlot = np.copy(Z)
        ZPlot[ZPlot<ls.ZBeachLevel] = ls.ZBeachLevel 
        ZPlot -= ls.ZBeachLevel
        ax1.plot_surface(X,Y,ZPlot, cmap = cm.terrain, rstride=1, cstride=1,
                antialiased=False,linewidth=0)

        ax2 = fig.add_subplot(122,aspect='equal')
        ax2.set_title('Elevation')

        #im = ax2.pcolor(Z,cmap=cm.terrain)
        im = ax2.pcolor(ZPlot,cmap=cm.coolwarm)
        cs = ax2.contour(ZPlot,6,colors='k')

        # Add a color bar which maps values to colors.
        cbar = fig.colorbar(im, shrink=0.5, aspect=5)
        # Add the contour line levels to the colorbar
        cbar.add_lines(cs)

        #plt.show()
        plt.draw()
        plt.pause(0.0001)

# %%
# Set up figure
# movie parameters
from matplotlib.animation import FFMpegWriter
metadata = dict(title='OCEAN',artist='laks',comment='creative')
writer = FFMpegWriter(fps=15, metadata=metadata,bitrate=200000)

fig = init_figure()
update_figure()
Znew = np.copy(Z)
    
with writer.saving(fig, "simulationparameterschanged.mp4", dpi=200):
    for it in range(1,n_iter+1):

        ls.calculate_collection_area(Z,NX,NY)
        ls.A *= dx*dy

        for i in range(NX):
            iL = np.mod(i-1,NX) # normally i-1 but observe p.b.c.
            iR = np.mod(i+1,NX) # normally i+1 but observe p.b.c.

            for j in range(NY):
                jD = np.mod(j-1,NY) # normally j-1 but observe p.b.c.
                jU = np.mod(j+1,NY) # normally j+1 but observe p.b.c.

                if ls.ocean[i,j]>0:
                    Psi_z  = 0;
                    Phi_z  = 0;
                else:
                    if ls.drain[i,j]>0: #this cell is a drain
                        s1 = (Z[iR,j]  - Z[iL,j] )/(2.*dx)
                        s2 = (Z[i,jU]  - Z[i,jD] )/(2.*dy)
                        s3 = (Z[iR,jD] - Z[iL,jU])/(2. * np.sqrt( dx**2 + dy**2) )
                        s4 = (Z[iR,jU] - Z[iL,jD])/(2. * np.sqrt( dx**2 + dy**2) )
                        gradient = (np.sqrt(s1**2 + s2**2) + np.sqrt(s3**2 + s4**2))/2.
                        Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)            
8
                    elif ls.drainage[i,j]>0: #this cell is a drainage point (it drains a pool)

                        if (Z[i,j]>=Z[iR,j]) and ls.pool[iR,j]!=ls.drainage[i,j]: 
                            gradient = (Z[i,j]-Z[iR,j])/dx #pool is on my left, I drain to the right, use this gradiant
                        elif (Z[i,j]>=Z[iL,j]) and ls.pool[iL,j]!=ls.drainage[i,j]:
                            gradient = (Z[i,j]-Z[iL,j])/dx
                        elif (Z[i,j]>=Z[i,jU]) and ls.pool[i,jU]!=ls.drainage[i,j]:
                            gradient = (Z[i,j]-Z[i,jU])/dy
                        elif (Z[i,j]>=Z[i,jD]) and ls.pool[i,jD]!=ls.drainage[i,j]:
                            gradient = (Z[i,j]-Z[i,jD])/dy
                        else:
                            gradient = 0.02 # ??? This does happen (maybe when two pools merge)
                        Psi_z = K * ( ls.A[i,j]**m * gradient**n - theta_c)

                    else: #this cell is a pool, assume it has some mass diffusion but no erosion!
                        Psi_z = 0.

                    if (Psi_z<0):
                        Psi_z = 0. 

                    # diffusion term
                    Phi_z = D * ( (Z[iR,j] - 2.*Z[i,j] + Z[iL,j]) / dx**2 \
                                + (Z[i,jU] - 2.*Z[i,j] + Z[i,jD]) / dx**2 )

                Znew[i,j] = Z[i,j] + (Phi_z - Psi_z + uplift )*dt  

                dZdt= (Znew[i,j] - Z[i,j]) / dt
                CFL = abs(dZdt) * dt / min(dx,dy)
                if (CFL>1.0):
                    print('\nWarning: Time step of',dt,'is probably too large. Safer would be:',dt/CFL)

                if (Znew[i,j]<0.):
                    Znew[i,j] = 0. # yes, this does happen at the boundary when kept at zero

        #Znew[0,:] = 0.0 # resets front boundary to 0
        Z = np.copy(Znew)

        ls.pool_check(Z,NX,NY)

        if (np.mod(it,10)==0): 
            print(it,end='')
            update_figure()
            writer.grab_frame()
            print(' Ocean level=',ls.ZBeachLevel,' Ocean surface fraction=',100*ls.AOcean/(NX*NY));
        else:
            print('.',end='')

    update_figure()
    writer.grab_frame()
    print(' Simulation finished.')
# Out:
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.50429699684404
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.07179319405222
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.0778421672585
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 152.18469166148196
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.92044855442882
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 158.55971606587352
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 133.18050771922765
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.25581365030934
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.55882035081646
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.50261541205668
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 128.89570266058885
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 154.23777444401603
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 125.98787961533898
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.58639068472408
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.31957914698293
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.31058946244323
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.25325989700032
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 102.41806181684265
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 112.52812463728708
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 130.51288174745673
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.32480352758478
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 97.30745207378726
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 107.82588604558468
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 123.7340962028662
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 104.49633290957053
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 93.75516209553685
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 104.68899968918281
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.1994892138018
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 101.24630894982911
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 91.3679414290264
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 102.68015257677112
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.31153506167952
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 99.14734998044061
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.80254481541856
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 101.3936173557571
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 114.55041900432532
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 97.8072789941548
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 88.72985576729255
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 100.42307216242152
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 113.4152047547035
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 96.83612186932037
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 87.81647134900967
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 99.35412000452675
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 112.39343555791757
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 95.8338968131513
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 86.72635185304021
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 97.78903357436968
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.96893929289466
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 94.40699518539388
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 85.14751837118872
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 95.41202483606747
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 108.67910564727104
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 92.21892592931088
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 82.8472236751918
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 92.07664891673072
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 105.21151813309866
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.06350193547131
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 79.73795999610358
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 87.75906653133387
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 100.5033823001243
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 84.93118182134685
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 75.83622453173015
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 82.58433340438728
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 94.66399672626693
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 79.94275279595749
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 71.27340639494545
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 76.78572138346195
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 87.95504738428342
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 74.3246906559276
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.25664125463929
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.6565658009617
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 80.7390832584871
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.36544261520072
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 61.02786944737263
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 64.49275953102648
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 73.40104825948677
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 62.358160114757574
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 55.82049189372273
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 58.381196965272586
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.27785508238246
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 56.55311048230588
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.70283069101007
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 34.44859619649137
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 59.78830720387821
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 51.257644307080106
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 54.88244908951959
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 30.394802953399367
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 43.91845760703606
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 39.42684094068843
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 40.89216541467322
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 37.22521238574774
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 38.54386667381082
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 35.489365645697
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 36.78045489993289
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 34.1787734709709
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 35.470667777737106
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 33.20719841806076
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 34.51799830678529
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.50777658690723
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 33.848331840672195
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.02652836717288
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 33.40210320847281
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.71805355548393
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 33.129203968845985
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.542680217495068
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.9755556305678
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.455436980376824
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.887530500499686
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.410808007208875
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.812428936756326
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.36382475707338
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.701302295350985
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.273080183112196
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.5123428189051
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.10400010828169
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 32.21456045044489
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 30.83209749929435
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.79100130774228
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 30.445589430928234
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 31.24015806075114
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 29.946279467061082
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 30.574899654992702
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 29.348254202455905
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 29.819512939818804
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 28.67505502976638
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 29.00570437598368
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 27.95612794662722
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 28.16872613994371
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 27.223561621019044
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 27.34415972876323
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 26.50950475260644
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 26.559364986404795
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 25.83849044767343
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 25.837427739143646
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 25.23129830482679
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 25.196375723231785
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 24.704329437395078
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 24.649529922882078
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 24.269953339774904
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 24.206189511083164
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 23.93710973901276
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 23.844998199477292
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 23.684921464286674
# .
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 63.2649752125035
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 56.51148226803149
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 62.85459108532206
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 172.4947947099127
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 170.70202034779132
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.58224787861923
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.5418402698881
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 161.1424289291948
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 155.22445566238466
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 169.9000976457937
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.79789418817376
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.1575238865751
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.19130867492228
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.09966290218185
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.20928617102248
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 153.2693496000573
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 129.51439615396325
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 137.59633310887264
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 167.3763629922001
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.65175376997323
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.49663457591224
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 125.80889772700276
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.67325494344018
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 127.97355722931684
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.44185378193549
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 114.0958576241979
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.58222435231858
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 115.8222007222381
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 99.54515012251575
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 67.53622348100163
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 137.00345638427098
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 111.92253033610328
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.05846585813345
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.001551137013195
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.61962729922217
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 65.8928882872982
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 59.15251238725502
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 61.32269771917979
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 55.824931619448456
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 57.8165640470504
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 53.234696086772104
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 55.17247454718854
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 51.269707720879794
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 53.208670968318444
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.81313703180841
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 51.78042365208905
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 48.764703539309
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.776587127493684
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 48.04345347559383
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.1080279965011
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.581474429452854
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.69980775771108
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.31946096116235
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.470497775970856
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.18967439552324
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.33934725234554
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.12355657523607
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.227340993690476
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.0536835961902
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 49.06104728372951
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 46.91793699723864
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 48.77773100280445
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 46.66443561924641
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 48.330889361906834
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 46.25643484532532
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 47.69509648144199
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 45.676266497949655
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 46.86812099850496
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 44.926663472544824
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 45.86930827551625
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 44.02879284456447
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 44.73512778982767
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 43.017999796640574
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 43.51315706985356
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 41.938465449007246
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 170.29974686308068
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 171.84195268644982
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 42.25655473373719
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 40.83857924527381
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.84094438735275
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.7755200150459
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 41.0189080857886
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 39.76676515954274
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 161.4270835063215
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 161.89249693192386
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 39.84107558269018
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 38.7596551398599
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 157.22209599931895
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 157.3219610072815
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 38.75755757465491
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 37.848297737984446
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 153.34107053843374
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 153.18648225167533
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 37.79540426826356
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 37.05730230209962
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.89478690573307
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.58051540426433
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 36.974606942855566
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 36.40523251329953
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.96998340932655
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.48526137609215
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 36.30383426471481
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 35.90033507753806
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 144.5463039483614
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.54031158002655
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 35.77197716550392
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 35.531802170595796
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.26768494304443
# .
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.16321966743726
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 79.34420008400406
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.5234815499808
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 78.95953411452268
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 138.668543176129
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.0193271269893
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.10624485455833
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.22286474489209
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 73.6405929351723
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 113.32782500346792
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 90.86960821609345
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 82.01834661057664
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 86.5643732506787
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 78.80394583660721
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 171.84532728840725
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 81.63440744267731
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 75.16371774136181
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 163.38266355172956
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 169.4622391190513
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 77.90424347152423
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 72.39202257070222
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.76236574411976
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 162.6388978306267
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 75.13201550535581
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.3359937337622
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.69766866520004
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 157.6090286668189
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 73.11568305242176
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.85598886183595
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.98628030015723
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 154.00492000455094
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 71.69838187927803
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 67.83775957789686
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 145.36825405288772
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.53127341922527
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.75462731718935
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 67.18574628689221
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.6236071589562
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.95959941680835
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.1786583914199
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.81626187647528
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.57664267191186
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.05795231477518
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 69.85524121787238
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.6334300158568
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.03886034072949
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 148.5601948776914
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 69.66995461516139
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.5400812184157
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.78468563218564
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 148.22788335836
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 69.51138808473833
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.44115628756613
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.6108648134622
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.83231253010206
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 69.27595527614531
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.24903338491642
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.32286881643387
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.16803237414933
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.87514205513921
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 65.89051558307519
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.74858859658332
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.06964739311255
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.24334604462547
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 65.31376898224849
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.75379269174553
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 144.42861850128557
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 67.3447167142483
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 64.49388573944324
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 138.25643748424335
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.20428046738846
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 66.17613705279011
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 63.43474779063401
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.23499595518564
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.4245292744638
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 64.76493746428639
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 62.166249215333885
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 133.72736243883423
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.17586996690844
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 63.162601357727524
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 60.738280846949266
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 130.82071794224277
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 132.58706605439986
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 61.43627567261639
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 59.21319213193425
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 127.63656724613091
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 128.81171406968855
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 59.661383900301516
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 57.6596459944307
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 124.31574312109406
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 125.02928437588854
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 57.91365168865926
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 56.14607936260174
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 121.02126051065348
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 121.3786542737753
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 56.25058272112536
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 54.72404749559396
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 117.87816859722389
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 117.96212977080071
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 54.72062511193337
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 53.43714425566121
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 114.97792777952847
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 114.87145520776113
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 53.361958421942205
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 52.32010517974876
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 112.40346611856116
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 112.17283035691557
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 52.20189801298096
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 51.39825885616602
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.21536570027264
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.85669693221459
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 51.2479485824238
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.6785962792867
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 108.40266942520812
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 107.92013947251048
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.887176230692944
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 50.53633408840299
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 106.9609874461532
# .
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 131.77314556547142
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 95.76504428059629
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 82.7425447192842
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 95.39921371919394
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 130.49903028532094
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 167.11038749745643
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 103.90631688251652
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.5302477774609
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 117.50248287761202
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 106.96874884699658
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.1834772609418
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 105.76643220573077
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 163.49086578589575
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 171.28860148985945
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.58529393575934
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 100.89628260808533
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.8532266877613
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 162.68979844259627
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 104.5844762709042
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 97.18129125007792
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 150.49631214245835
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.14559673830257
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 100.86351962343417
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 94.4218572989895
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 145.63960675657958
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.31343506288695
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 98.15648608597324
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 92.4349780984882
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.07369371987687
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.84977905819892
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 96.25324027025461
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 91.06766634393277
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.55714558313596
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 145.4721065346286
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 94.98587627428036
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 90.19213707848209
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 137.87966368943196
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.9586757069085
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 94.21220397432903
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.69586521931286
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.8704505993323
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.08599809224114
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 93.77738301022985
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.45001774222482
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.34779563567471
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.60311461224393
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 93.52731406929112
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.32370272254637
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.09927278911908
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.2798242936144
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 93.31270890443433
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 89.18955824068765
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 135.9286062652596
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.8966526678889
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 92.99473850577208
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 88.9301642781144
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 135.64912952593332
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.25652867230374
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 92.45475644401691
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 88.44741371963401
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 135.09576043645632
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.2008819970828
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 91.60484958861396
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 87.67185018925424
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 134.13981598632998
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 138.62561287295497
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 90.3969977804622
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 86.5701171244357
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 132.70260826381804
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.49164362913282
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 88.8270553094077
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 85.14744351299764
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 130.76342221554413
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 133.82557432494914
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 86.93169434628916
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 83.44392970344522
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 128.35846471724346
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 130.71026833538625
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 84.77995727844387
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 81.52647604795081
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 125.5712653323792
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 127.26918482982052
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 82.46192193347908
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 79.47872073412334
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 122.51833856951737
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 123.65058122722006
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 80.07928814275483
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 77.39325971273747
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 119.33565327503476
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 120.02314854623464
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 77.73355020612628
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 75.36182631217649
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.17637036295405
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.52091291944039
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 75.50174224717831
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 73.45349320624717
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 113.16118088574287
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 113.2435843014778
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 73.44847300868527
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 71.7263868880761
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.37929332558528
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.2785675363914
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 71.62479962819313
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.22695385344092
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 107.90969025488094
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 107.68528799247973
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 70.06533442989215
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.9872011528097
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 105.80654287693896
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 105.46295894497578
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.77867207360103
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 68.01501149503132
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 104.06739133186474
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 103.95909950085905
#
# ...
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 120.78015620225247
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 112.5193215619939
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.79012753250352
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 118.67460434114747
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 118.30241272341749
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 110.52768064520556
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 109.29861621869222
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.73772612781067
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 117.81260307553633
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 114.02637785486516
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 113.14946531817994
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 116.706638715564
# .
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 154.0170415594288
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.1732286716068
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.4176401001094
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 148.79561139383048
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 152.8104997607181
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.4789405410639
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 170.93480003124938
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.87825299311322
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 167.6375856970568
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.9891113206835
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.67779047696305
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.4604839404259
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 173.4786124756145
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.1093036190057
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 172.97231416845466
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 172.52424142167797
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.4229657268425
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 171.66956086028952
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 171.00044188053542
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 164.24468225565454
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 169.7322508660769
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.8427530276818
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 162.47863700811132
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 167.11283654678724
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 173.23598391287857
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.06143486852562
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.09965310638415
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 163.84380791166618
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 169.53253397844642
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 162.73438116622432
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 157.15191098736656
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.02637691697277
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.33107684655997
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 158.99148488872407
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 153.73740297938357
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 155.8116772012562
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.80736547488164
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 154.99591750889573
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 149.99873884290602
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.38392690957716
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.16188621292335
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 150.93030204872704
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.10491730458915
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.94477580426462
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.59031756683345
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 146.9715259538395
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.23896810256537
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.65832851894757
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 147.2426087607328
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.25412347939798
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 138.54869498682825
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 138.64712274976452
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 143.24175004596128
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.88868421625523
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 135.14378379601112
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 135.0136471693778
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.68332956544162
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.96199241343564
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 132.11664078747881
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 131.823122418598
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 136.62552224590178
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 129.52623983995267
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 129.14780895010188
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 134.3468617361859
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 127.43911264524361
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 129.35597837211725
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 140.11976487765762
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 139.01158234745037
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 128.11429954621042
# .
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.97935405177765
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.8201944254025
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 157.41713952789965
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.42043829041643
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 165.73303243557316
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.59957941283224
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 172.34440431381634
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 168.5978150204587
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 170.86951444455758
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 164.49623603407312
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 166.01329298476102
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 160.2258042246886
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 161.14499599358277
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 155.98621088692403
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 156.4441572346656
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 151.93915969609242
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 152.0446784890313
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 148.20449968643302
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 148.05717275507388
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 144.88186958700817
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 144.55417505222195
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 155.7396435124233
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 141.67629417183915
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 169.30934691954317
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 142.70316821127471
#
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 155.0473890287796
# ..10 Ocean level= 110.59741125949982  Ocean surface fraction= 31.305555555555557
# .........20 Ocean level= 110.54161476768674  Ocean surface fraction= 31.916666666666668
# .........30 Ocean level= 110.54161476768674  Ocean surface fraction= 32.02777777777778
# ........
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 61.41332909513533
# .40 Ocean level= 110.52648955286529  Ocean surface fraction= 32.111111111111114
# .........50 Ocean level= 110.52648955286529  Ocean surface fraction= 32.138888888888886
# .........60 Ocean level= 110.52648955286529  Ocean surface fraction= 32.166666666666664
# .........70 Ocean level= 110.52648955286529  Ocean surface fraction= 32.166666666666664
# .........80 Ocean level= 110.52648955286529  Ocean surface fraction= 32.166666666666664
# .........90 Ocean level= 110.52648955286529  Ocean surface fraction= 32.166666666666664
# .........100 Ocean level= 110.52648955286529  Ocean surface fraction= 32.166666666666664
# ......
# Warning: Time step of 173.61111111111111 is probably too large. Safer would be: 150.00395312581344
# ...110 Ocean level= 110.5244931911418  Ocean surface fraction= 32.19444444444444
# .........120 Ocean level= 110.52104300545442  Ocean surface fraction= 32.22222222222222
# .........130 Ocean level= 110.52104300545442  Ocean surface fraction= 32.22222222222222
# .........140 Ocean level= 110.5177185759164  Ocean surface fraction= 32.333333333333336
# .........150 Ocean level= 110.5177185759164  Ocean surface fraction= 32.333333333333336
# .........160 Ocean level= 110.5177185759164  Ocean surface fraction= 32.44444444444444
# .........170 Ocean level= 110.5177185759164  Ocean surface fraction= 32.47222222222222
# .........180 Ocean level= 110.51673099155617  Ocean surface fraction= 32.55555555555556
# .........190 Ocean level= 110.51610535879743  Ocean surface fraction= 32.666666666666664
# .........200 Ocean level= 110.51435753652454  Ocean surface fraction= 32.80555555555556
# .........210 Ocean level= 110.51385895214608  Ocean surface fraction= 32.97222222222222
# .........220 Ocean level= 110.51385895214608  Ocean surface fraction= 33.138888888888886
# .........230 Ocean level= 110.51385895214608  Ocean surface fraction= 33.22222222222222
# .........240 Ocean level= 110.51385895214608  Ocean surface fraction= 33.27777777777778
# .........250 Ocean level= 110.51385895214608  Ocean surface fraction= 33.333333333333336
# .........260 Ocean level= 110.51385895214608  Ocean surface fraction= 33.361111111111114
# .........270 Ocean level= 110.51385895214608  Ocean surface fraction= 33.388888888888886
# .........280 Ocean level= 110.51385895214608  Ocean surface fraction= 33.416666666666664
# .........290 Ocean level= 110.51385895214608  Ocean surface fraction= 33.52777777777778
# .........300 Ocean level= 110.51385895214608  Ocean surface fraction= 33.611111111111114
# .........310 Ocean level= 110.51360100144522  Ocean surface fraction= 33.69444444444444
# .........320 Ocean level= 110.51346751043086  Ocean surface fraction= 33.80555555555556
# .........330 Ocean level= 110.51346751043086  Ocean surface fraction= 33.861111111111114
# .........340 Ocean level= 110.51298311213162  Ocean surface fraction= 33.97222222222222
# .........350 Ocean level= 110.51298311213162  Ocean surface fraction= 34.05555555555556
# .........360 Ocean level= 110.51298311213162  Ocean surface fraction= 34.05555555555556
# .........370 Ocean level= 110.51298311213162  Ocean surface fraction= 34.138888888888886
# .........380 Ocean level= 110.51298311213162  Ocean surface fraction= 34.138888888888886
# .........390 Ocean level= 110.51298311213162  Ocean surface fraction= 34.22222222222222
# .........400 Ocean level= 110.51149805002252  Ocean surface fraction= 34.27777777777778
# .........410 Ocean level= 110.51149805002252  Ocean surface fraction= 34.30555555555556
# .........420 Ocean level= 110.51149805002252  Ocean surface fraction= 34.333333333333336
# .........430 Ocean level= 110.51149805002252  Ocean surface fraction= 34.388888888888886
# .........440 Ocean level= 110.51149805002252  Ocean surface fraction= 34.416666666666664
# .........450 Ocean level= 110.51149805002252  Ocean surface fraction= 34.47222222222222
# .........460 Ocean level= 110.51149805002252  Ocean surface fraction= 34.583333333333336
# .........470 Ocean level= 110.51149805002252  Ocean surface fraction= 34.666666666666664
# .........480 Ocean level= 110.51149805002252  Ocean surface fraction= 34.80555555555556
# .........490 Ocean level= 110.50613287675611  Ocean surface fraction= 34.47222222222222
# .........500 Ocean level= 110.49824388838377  Ocean surface fraction= 35.416666666666664
# .........510 Ocean level= 110.4976269654131  Ocean surface fraction= 35.611111111111114
# .........520 Ocean level= 110.4976269654131  Ocean surface fraction= 35.69444444444444
# .........530 Ocean level= 110.4976269654131  Ocean surface fraction= 35.72222222222222
# .........540 Ocean level= 110.4976269654131  Ocean surface fraction= 35.77777777777778
# .........550 Ocean level= 110.4976269654131  Ocean surface fraction= 35.97222222222222
# .........560 Ocean level= 110.49754251451219  Ocean surface fraction= 36.111111111111114
# .........570 Ocean level= 110.49754251451219  Ocean surface fraction= 36.22222222222222
# ...... Simulation finished.

# %%
#(1)

#Describe in your own words, how the initial conditions are chosen and what geological features they represent.
#A: NX and NY are the number of rows and columns. d, dx, and dy are used in calculation of the rates of spacing. 
# Z is the initial set of random values that is generated for the height map of the array. xx, yy, r, and h are all random values mostly based on NX or NY. The values of Z are set to randomly generated hills. 
# They represent randomly generated hills as NX and NY varies, which causes the other variables to vary.

#Have a look inside landscapeWithOcean.py and give an interpretation of the variable ‘oceanLevelParameter’.  
#A: Since the landscape usually varied from a height from 0 to 1, the oceanLevelParameter was set to 0.1 by default. This meant values larger than 0.1 would not be submerged. Larger values of oceanLevelParameter means a higher ocean level and more submerged land.

#Run the code several times and describe the resulting evolution. Say how the geological features change with time. What happens in the ocean? 
#A: The resulting evolution shows the maximum height of the landscape decrease as erosion by water causes the height to decrease. The landscape becomes softened out. Hills and mountains become less sharp and pronounced. The ocean seems to envelope the land as much of the land submerges itself into the ocean over time from erosion.

# %%
#(2) 

#Describe what geological features you were trying to model even if their representation is not perfect.
#A: I was trying to model the effects of land mass presence in causing erosion as time goes by. From the simulation, we can see that there is a large blob of land connected to what seems like a box of thin barriers. The shape shows how the thin barriers, when not in near proximity to the large chunk of land, flattens out to allow a trough of water to flow through. However, the barriers that were connected to the large piece of land remained above water. Rather than being submerged, it was relatively smoothed out and showed how the ocean maneuvered around the land masses and caused some areas to submerge while others to remain above water.

#Briefly describe how your landscape evolved and identify effects that are missing from your simulation if there are any.
#A: As time in the simulation progresses, the barriers that were not connected to the large mass of land caved outwards as water eroded it away. The barriers connected to the large mass in the center remained higher than those that were not connected. The effect of the land mass being nearly submerged was not available due to the rate of erosion and time step not being changed to display this.

# %%
#(3)

#Effects the parameter changes had:
#K: The K value determines the zoom and perspective of the graph. Larger values of K were more zoomed out while smaller values were more zoomed in. This could be attributed to a faster rate of erosion.
#D: Larger values of D reduced the time step, which is important in monitoring the change through erosion. 
#n: The area exponent allows for larger areas of erosion to occur. Increases in this value showed the height and length changes.
#m: Higher values of the gradient exponent allowed for larger gradients when simulating. These gradients stretched out significantly more. 
#the ocean level: Higher values of the ocean level increases the ocean level. With all positive values, an ocean level of 0 would mean all of the land mass is above water.
#dt: The higher the time step, the more noticeable change through erosion was. 
#the spatial resolution: Increases in this allowed for better viewing through higher resolution.

#some interesting effects: The changes in water level allowed for the creation of some beautiful graphs as it becomes much easier to note height change differences from the simulation.
