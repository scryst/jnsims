# %%
# Part 1 – Mandelbrot and Julia Sets
import numpy as np
import matplotlib.pyplot as plt

def Mandelbrot(z,C):
    zNew = z**2 + C
    return zNew

# %%
# Part 1 – Mandelbrot and Julia Sets (1)
zmax = 30

n = 501 #Iteration number

x = np.linspace(-1.5,1.5,n)
y = np.linspace(-1.5,1.5,n)

C = [-0.4+0.6j]



def f(Z):
    for C1 in C:
        z_0 = Z
        for i in range(0,zmax):
            z_0 = Mandelbrot(z_0,C1)
            if abs(z_0) > 50:
                return 1
                break
        return 0
    return('did not diverge')
    
julia = np.zeros((n,n))


for a in range(n):
    for b in range(n):   
        Z = complex(x[a],y[b])
        julia[a,b]=f(Z)
        #if f(Z).z_0 >= zmax: #xlim ylim
            #print(a,b)
            #break
            
for i in range(len(x)):
    y[i] = f(x[i])
    
plt.plot(x,y,'-o')
plt.xlabel('Z values')
plt.ylabel('f(Z)')
plt.show()
    
    
plt.figure(figsize = (20,20))    
    
plt.xlim(0,500)
plt.ylim(0,500)
#plt.xlim(a,b)
#plt.ylim(a,b)

plt.imshow(julia)

# %%
# Part 1 – Mandelbrot and Julia Sets (2)
zmax = 30

n = 501 #Iteration number

#x = np.linspace(-0.049,-0.046,n)
#y = np.linspace(-0.238,-0.235,n)
x = np.linspace(-0.75825,-0.75785,n)
y = np.linspace(0.07785,0.07825,n)

C = [-0.4+0.6j]

def f(Z):
    for C1 in C:
        z_0 = Z
        for i in range(0,zmax):
            z_0 = Mandelbrot(z_0,C1)
            if abs(z_0) > 50:
                return 1
                break
        return 0
    return('did not diverge')
    
julia = np.zeros((n,n))


for a in range(n):
    for b in range(n):   
        Z = complex(x[a],y[b])
        julia[a,b]=f(Z)
        if julia[a,b] >= zmax: #xlim ylim
            print(a,b)
            break
            
for i in range(len(x)):
    y[i] = f(x[i])
    
plt.plot(x,y,'-o')
plt.xlabel('Z values')
plt.ylabel('f(Z)')
plt.show()
    
    
plt.figure(figsize = (20,20))    
    
plt.xlim(0,501)
plt.ylim(0,501)
#plt.xlim(a,b)
#plt.ylim(a,b)

plt.imshow(julia)

# %%
# Part 1 – Mandelbrot and Julia Sets (3)
zmax = 30

n = 501 #Iteration number

x = np.linspace(-1.5,1.5,n)
y = np.linspace(-1.5,1.5,n)

C = [-0.85+0.22j]

def f(Z):
    for C1 in C:
        z_0 = Z
        for i in range(0,zmax):
            z_0 = Mandelbrot(z_0,C1)
            if abs(z_0) > 50:
                return 1
                break
        return 0
    return('did not diverge')
    
julia = np.zeros((n,n))


for a in range(n):
    for b in range(n):   
        Z = complex(x[a],y[b])
        julia[a,b]=f(Z)
        if julia[a,b] >= zmax: #xlim ylim
            print(a,b)
            break
            
for i in range(len(x)):
    y[i] = f(x[i])
    
plt.plot(x,y,'-o')
plt.xlabel('Z values')
plt.ylabel('f(Z)')
plt.show()
    
    
plt.figure(figsize = (20,20))    
    
plt.xlim(0,500)
plt.ylim(0,500)
#plt.xlim(a,b)
#plt.ylim(a,b)

plt.imshow(julia,cmap='cividis')

# %%
# Part 1 – Mandelbrot and Julia Sets (4)

zmax = 30

n = 501 #Iteration number

x = np.linspace(-0.2318,-0.2314,n) #Comment: x-values interval
y = np.linspace(-0.1286,-0.1282,n) #Comment: y-values interval

C = [-0.85+0.22j]

def f(Z):
    for C1 in C:
        z_0 = Z
        for i in range(0,zmax):
            z_0 = Mandelbrot(z_0,C1)
            if abs(z_0) > 50:
                return 1
                break
        return 0
    return('did not diverge')
    
julia = np.zeros((n,n))


for a in range(n):
    for b in range(n):   
        Z = complex(x[a],y[b])
        julia[a,b]=f(Z)
        if julia[a,b] >= zmax: #xlim ylim
            print(a,b)
            break
            
for i in range(len(x)):
    y[i] = f(x[i])
    
plt.plot(x,y,'-o')
plt.xlabel('Z values')
plt.ylabel('f(Z)')
plt.show()
    
    
plt.figure(figsize = (20,20))    
    
plt.xlim(0,500)
plt.ylim(0,500)
#plt.xlim(a,b)
#plt.ylim(a,b)

print(C) # Comment: Complex number C
print('x-values interval from -0.2318 to -0.2314')
print('y-values interval from -0.1286 to -0.1282')

plt.imshow(julia,cmap='cividis')
# Out:
# [(-0.85+0.22j)]
# x-values interval from -0.2318 to -0.2314
# y-values interval from -0.1286 to -0.1282
